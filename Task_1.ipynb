# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/Daily_Public_Transport_Passenger_Boardings_By_Ticket_Type_20240513.csv")

# %%
df
# Out:
#             Date  MyWay  Paper Ticket
# 0     01/07/2019  66215          4325
# 1     15/09/2023  63800          7349
# 2     28/12/2021   9994          1882
# 3     11/01/2023  43769          3991
# 4     11/09/2021   3810           685
# ...          ...    ...           ...
# 1773  19/01/2023  46083          4622
# 1774  16/08/2023  70115          6955
# 1775  10/01/2022  21932          2315
# 1776  04/05/2020  14842           854
# 1777  26/07/2023  69067          6811
#
# [1778 rows x 3 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#         Date  MyWay  Paper Ticket
# 0 2019-07-01  66215          4325
# 1 2023-09-15  63800          7349
# 2 2021-12-28   9994          1882
# 3 2023-01-11  43769          3991
# 4 2021-09-11   3810           685

# %%
df1 = df.loc[(df['Date'] >= '2023-04-01')
                     & (df['Date'] < '2024-04-30')]

# %%
df1
# Out:
#            Date  MyWay  Paper Ticket
# 1    2023-09-15  63800          7349
# 10   2023-08-29  69155          6507
# 19   2023-04-11  50246          4306
# 27   2023-09-17  19207          2368
# 33   2023-10-07  24249          3089
# ...         ...    ...           ...
# 1767 2024-03-20  76782          1346
# 1768 2023-07-13  49311          4309
# 1770 2024-04-14  18001          2844
# 1774 2023-08-16  70115          6955
# 1777 2023-07-26  69067          6811
#
# [395 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df1['MyWay'].plot(kind='hist', bins=20, title='MyWay')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df1['Paper Ticket'].plot(kind='hist', bins=20, title='Paper Ticket')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
df1.head()
# Out:
#          Date  MyWay  Paper Ticket
# 1  2023-09-15  63800          7349
# 10 2023-08-29  69155          6507
# 19 2023-04-11  50246          4306
# 27 2023-09-17  19207          2368
# 33 2023-10-07  24249          3089

# %%
df1.sort_values(by='Date')
print(df1)
# Out:
#            Date  MyWay  Paper Ticket
# 1    2023-09-15  63800          7349
# 10   2023-08-29  69155          6507
# 19   2023-04-11  50246          4306
# 27   2023-09-17  19207          2368
# 33   2023-10-07  24249          3089
# ...         ...    ...           ...
# 1767 2024-03-20  76782          1346
# 1768 2023-07-13  49311          4309
# 1770 2024-04-14  18001          2844
# 1774 2023-08-16  70115          6955
# 1777 2023-07-26  69067          6811
#
# [395 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 395 entries, 1 to 1777
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          395 non-null    datetime64[ns]
#  1   MyWay         395 non-null    int64
#  2   Paper Ticket  395 non-null    int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 12.3 KB

# %%
df1.describe()
# Out:
#                                 Date         MyWay  Paper Ticket
# count                            395    395.000000    395.000000
# mean   2023-10-14 23:59:59.999999744  48259.362025   4776.812658
# min              2023-04-01 00:00:00   2345.000000    373.000000
# 25%              2023-07-08 12:00:00  23245.500000   2590.000000
# 50%              2023-10-15 00:00:00  56693.000000   4727.000000
# 75%              2024-01-21 12:00:00  66432.500000   6897.000000
# max              2024-04-29 00:00:00  79279.000000  10154.000000
# std                              NaN  21763.542987   2531.565481

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1[['Paper Ticket']].boxplot()
# Out:
# <Axes: >

# %%
df1[['MyWay']].boxplot()
# Out:
# <Axes: >

# %%
df1.corr()
# Out:
#                   Date     MyWay  Paper Ticket
# Date          1.000000  0.041527     -0.155535
# MyWay         0.041527  1.000000      0.680496
# Paper Ticket -0.155535  0.680496      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
  sns_plot = sns.distplot(df1["MyWay"])

# %%
sns_plot2=sns.distplot(df1["Paper Ticket"])

# %%
from pandas.plotting import autocorrelation_plot


autocorrelation_plot(df1['Paper Ticket'])
plt.show()
